# %% [markdown]
# Feras Saleh Alzahrani
# Ahmed alghamdi

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('library.db')
c = conn.cursor()

# Create Books table
c.execute('''
CREATE TABLE IF NOT EXISTS Books (
    id INTEGER PRIMARY KEY,
    title TEXT NOT NULL,
    author TEXT NOT NULL,
    published_year INTEGER
)
''')

# Create Members table
c.execute('''
CREATE TABLE IF NOT EXISTS Members (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    email TEXT NOT NULL,
    join_date TEXT NOT NULL
)
''')

# Create Borrowing table
c.execute('''
CREATE TABLE IF NOT EXISTS Borrowing (
    id INTEGER PRIMARY KEY,
    book_id INTEGER,
    member_id INTEGER,
    borrow_date TEXT NOT NULL,
    return_date TEXT,
    FOREIGN KEY (book_id) REFERENCES Books (id),
    FOREIGN KEY (member_id) REFERENCES Members (id)
)
''')

# Commit changes and close connection
conn.commit()
conn.close()

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('library.db')
c = conn.cursor()

# Create Books table
c.execute('''
CREATE TABLE IF NOT EXISTS Books (
    id INTEGER PRIMARY KEY,
    title TEXT NOT NULL,
    author TEXT NOT NULL,
    published_year INTEGER
)
''')

# Create Members table
c.execute('''
CREATE TABLE IF NOT EXISTS Members (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    email TEXT NOT NULL,
    join_date TEXT NOT NULL
)
''')

# Create Borrowing table
c.execute('''
CREATE TABLE IF NOT EXISTS Borrowing (
    id INTEGER PRIMARY KEY,
    book_id INTEGER,
    member_id INTEGER,
    borrow_date TEXT NOT NULL,
    return_date TEXT,
    FOREIGN KEY (book_id) REFERENCES Books (id),
    FOREIGN KEY (member_id) REFERENCES Members (id)
)
''')

# Commit changes and close connection
conn.commit()
conn.close()

import sqlite3
from datetime import date

# Connect to SQLite database
conn = sqlite3.connect('library.db')
c = conn.cursor()

# Add a new book
c.execute('''
INSERT INTO Books (title, author, published_year) 
VALUES (?, ?, ?)
''', ('The Great Gatsby', 'F. Scott Fitzgerald', 1925))

# Add a new member
c.execute('''
INSERT INTO Members (name, email, join_date) 
VALUES (?, ?, ?)
''', ('John Doe', 'john.doe@example.com', date.today().isoformat()))

# Add a new borrowing
c.execute('''
INSERT INTO Borrowing (book_id, member_id, borrow_date) 
VALUES (?, ?, ?)
''', (1, 1, date.today().isoformat()))

# Commit changes and close connection
conn.commit()
conn.close()

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('library.db')
c = conn.cursor()

# Simulate an SQL injection
user_input = "1 OR 1=1"
query = f"SELECT * FROM Members WHERE id = {user_input}"

print("Executing SQL injection query:")
for row in c.execute(query):
    print(row)

# Close connection
conn.close()
# Out:
# Executing SQL injection query:
# (1, 'John Doe', 'john.doe@example.com', '2024-07-02')
# (2, 'John Doe', 'john.doe@example.com', '2024-07-02')
# (3, 'John Doe', 'john.doe@example.com', '2024-07-02')
